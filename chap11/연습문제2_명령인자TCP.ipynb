# %% [markdown]
# ## 11단원 실습
# 날  짜 : 2025.11.05.수요일 (10주차 실습) <br>
# 작성자 : 문효원 <br>
# 학  번 : 202311398 <br>
# *****

# %% [markdown]
# 1. TCP_echoserver.py를 먼저 실행한다
# > C:>py TCP_echoserver.py<br>
# 실제 실행 : C:>py echo_server.py
# 2. -p 2500 명령 인자와 함께 Dummy_TCP_client_arg.py를 실행한다
# > C:>py Dummy_TCP_client_arg.py –p 2500<br>
# 실제 실행 : python "F:\1. NP\NP_2025_202311398\chap11\TCP_part\Dummy_TCP_client_arg.py" 127.0.0.1 -p 2500
#
# ![image.png](attachment:image.png)
