# %% [markdown]
# ## 9단원 실습
# 날  짜 : 2025.10.15.수요일 (7주차 실습) <br>
# 작성자 : 문효원 <br>
# 학  번 : 202311398 <br>
# *****

# %% [markdown]
# ### 서로 통신 확인하기 (Ping Test)
# > Linux (Ctrl + C 강제종료 할 때까지 반복됨)
#
# 1. Linux<br>
# ![image-2.png](attachment:image-2.png)
#
# 2. Windows<br>
#  - Windows의 핑 테스트를 성공하기 위해선 Windows Defender 방화벽의 인바우드 규칙에서 아래를 셋 다 허용해주어야 한다.
# ![image-5.png](attachment:image-5.png)
# ![image-4.png](attachment:image-4.png)
# <br>
#
# > Windows
#
# 1. Linux<br>
# ![image.png](attachment:image.png)
#
# 2. Windows<br>
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### X윈도우 applications on X Server of mobaxterm
# > xeyes 설치 X
#
# ![image-2.png](attachment:image-2.png)
#
# > 실행 화면
#
# ![image-3.png](attachment:image-3.png)
